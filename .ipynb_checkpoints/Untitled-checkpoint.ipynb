# %%
from twython import Twython, TwythonStreamer
from auth import *
from datetime import datetime
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
import pyodbc
conn = pyodbc.connect(r'DSN=SQL_DSN;UID=python;PWD=password')
cur = conn.cursor()

# %%
tweets = []
analyser = SentimentIntensityAnalyzer()

# %%
class MyTwythonStreamer(TwythonStreamer):
    def on_success(self, data):
        if data['lang'] == 'en':
            tweets.append(data)
            print('Recieved tweet #{}'.format(len(tweets)))
        if len(tweets)>= 20:
            self.disconnect()
    def on_error(self, status_code, data):
        print(status_code, data)
        self.disconnect()

# %%
class MyTwythonStreamer(TwythonStreamer):
    def on_success(self, data):
        if data['lang'] == 'en':
            tweet_text = data['text']
            tweet_date = data['timestamp_ms']
            compound_sentiment = analyser.polarity_scores(tweet_text)['compound']
            name = data['user']['name']
            screen_name = data['user']['screen_name']
            twitter_bio = data['user']['description']
            follower_count = data['user']['followers_count']
            friends_count = data['user']['friends_count']
            statuses_count = data['user']['statuses_count']
            favourites_count = data['user']['favourites_count']
            profile_image_url = data['user']['profile_image_url_https']
            tweet_identity = data['id']
            q = 'INSERT INTO twitter.tweets_grabbed VALUES(?,?,?,?,?,?,?,?,?,?,?,?)'
            cur.execute(q, tweet_date, tweet_text, compound_sentiment, name, screen_name, twitter_bio, follower_count, friends_count, statuses_count, favourites_count,  profile_image_url, tweet_identity )
            cur.commit()
            print('Recieved tweet #{}'.format(len(tweets)))
        if len(tweets)>= 20:
            self.disconnect()
    def on_error(self, status_code, data):
        print(status_code, data)
        self.disconnect()

# %%
stream = MyTwythonStreamer(CONSUMER_KEY, CONSUMER_SECRET, ACCESS_TOKEN, ACCESS_TOKEN_SECRET)

# %%
stream.statuses.filter(track='UFO, alien, aliens, martian')
# Out:
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# <ipython-input-165-abad4d1bf260> in <module>()
# ----> 1 stream.statuses.filter(track='UFO, alien, aliens, martian')
#
# c:\environments\politics\lib\site-packages\twython\streaming\types.py in filter(self, **params)
#      64         url = 'https://stream.twitter.com/%s/statuses/filter.json' \
#      65               % self.streamer.api_version
# ---> 66         self.streamer._request(url, 'POST', params=params)
#      67
#      68     def sample(self, **params):
#
# c:\environments\politics\lib\site-packages\twython\streaming\api.py in _request(self, url, method, params)
#     152                                       not valid JSON.')
#     153                     else:
# --> 154                         if self.on_success(data):  # pragma: no cover
#     155                             for message_type in self.handlers:
#     156                                 if message_type in data:
#
# <ipython-input-163-69589edfe930> in on_success(self, data)
#      19             cur.commit()
#      20             print('Recieved tweet #{}'.format(len(tweets)))
# ---> 21         if len(tweets)>= 20:
#      22             self.disconnect()
#      23     def on_error(self, status_code, data):
#
# UnboundLocalError: local variable 'tweets' referenced before assignment

# %%
tweet_collection = {}
for c in range(0,len(tweets)-1):
    text = tweets[c]['text']
    sentiment = analyser.polarity_scores(text)
    tweet_collection[text]= sentiment

# %%
for c in range(0,len(tweets)-1):
    tweet_text = tweets[c]['text']
    tweet_date = tweets[c]['timestamp_ms']
    compound_sentiment = analyser.polarity_scores(tweet_text)['compound']
    name = tweets[c]['user']['name']
    screen_name = tweets[c]['user']['screen_name']
    twitter_bio = tweets[c]['user']['description']
    follower_count = tweets[c]['user']['followers_count']
    friends_count = tweets[c]['user']['friends_count']
    statuses_count = tweets[c]['user']['statuses_count']
    favourites_count = tweets[c]['user']['favourites_count']
    profile_image_url = tweets[c]['user']['profile_image_url_https']
    tweet_identity = tweets[c]['id']
    q = 'INSERT INTO twitter.tweets_grabbed VALUES(?,?,?,?,?,?,?,?,?,?,?,?)'
    cur.execute(q, tweet_date, tweet_text, compound_sentiment, name, screen_name, twitter_bio, follower_count, friends_count, statuses_count, favourites_count,  profile_image_url, tweet_identity )
    cur.commit()

# %%
tweets[9]['extended_tweet']['full_text']
# Out:
# '@RodStryker Wth is going on to our country? The government of Cali and others are hell bent in destroying the USA. Gotta vote these fools out. No more illegal aliens. #BuildtheWall #BuildTheWall #TrumpTrain #Trump2020 #NoDACA'

# %%
tweets
# Out:
# [{'created_at': 'Mon Apr 30 15:42:42 +0000 2018',
#   'id': 990979764642033664,
#   'id_str': '990979764642033664',
#   'text': '@birdhism Have you ever heard of Tigres Volants? A really cool scifi french rpg. Scifi with elves, alien lizards, a… https://t.co/X0SHgT4Y8j',
#   'display_text_range': [10, 140],
#   'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#   'truncated': True,
#   'in_reply_to_status_id': 990969954102140928,
#   'in_reply_to_status_id_str': '990969954102140928',
#   'in_reply_to_user_id': 1866211717,
#   'in_reply_to_user_id_str': '1866211717',
#   'in_reply_to_screen_name': 'birdhism',
#   'user': {'id': 2407674142,
#    'id_str': '2407674142',
#    'name': 'Howonda Parakeet',
#    'screen_name': 'ardorwen',
#    'location': None,
#    'url': None,
#    'description': None,
#    'translator_type': 'none',
#    'protected': False,
#    'verified': False,
#    'followers_count': 353,
#    'friends_count': 1193,
#    'listed_count': 11,
#    'favourites_count': 5415,
#    'statuses_count': 1849,
#    'created_at': 'Thu Mar 13 14:39:19 +0000 2014',
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'lang': 'fr',
#    'contributors_enabled': False,
#    'is_translator': False,
#    'profile_background_color': 'C0DEED',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/987632102219878400/uzgNenwt_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/987632102219878400/uzgNenwt_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/2407674142/1521917247',
#    'default_profile': True,
#    'default_profile_image': False,
#    'following': None,
#    'follow_request_sent': None,
#    'notifications': None},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'is_quote_status': False,
#   'extended_tweet': {'full_text': '@birdhism Have you ever heard of Tigres Volants? A really cool scifi french rpg. Scifi with elves, alien lizards, alien bears and a lot of mutants. And a religion named Hellokittism...',
#    'display_text_range': [10, 184],
#    'entities': {'hashtags': [],
#     'urls': [],
#     'user_mentions': [{'screen_name': 'birdhism',
#       'name': 'Cody the Lovebird ❤',
#       'id': 1866211717,
#       'id_str': '1866211717',
#       'indices': [0, 9]}],
#     'symbols': []}},
#   'quote_count': 0,
#   'reply_count': 0,
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'entities': {'hashtags': [],
#    'urls': [{'url': 'https://t.co/X0SHgT4Y8j',
#      'expanded_url': 'https://twitter.com/i/web/status/990979764642033664',
#      'display_url': 'twitter.com/i/web/status/9…',
#      'indices': [117, 140]}],
#    'user_mentions': [{'screen_name': 'birdhism',
#      'name': 'Cody the Lovebird ❤',
#      'id': 1866211717,
#      'id_str': '1866211717',
#      'indices': [0, 9]}],
#    'symbols': []},
#   'favorited': False,
#   'retweeted': False,
#   'filter_level': 'low',
#   'lang': 'en',
#   'timestamp_ms': '1525102962061'},
#  {'created_at': 'Mon Apr 30 15:42:43 +0000 2018',
#   'id': 990979772368019457,
#   'id_str': '990979772368019457',
#   'text': 'BEING*\n\nAS IN MY #ALIEN LIFE. \n\n@RealDonaldTrump #NEWS #BREAKING #HOLLYWOOD #NYC #DC  @USAF_ACC  @FBI  @CIA @POTUS… https://t.co/OqemH70Xnn',
#   'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Lite</a>',
#   'truncated': True,
#   'in_reply_to_status_id': 990979475381850119,
#   'in_reply_to_status_id_str': '990979475381850119',
#   'in_reply_to_user_id': 963890107446067203,
#   'in_reply_to_user_id_str': '963890107446067203',
#   'in_reply_to_screen_name': 'aliengodboy',
#   'user': {'id': 963890107446067203,
#    'id_str': '963890107446067203',
#    'name': 'Jared Morrison',
#    'screen_name': 'aliengodboy',
#    'location': 'LITTLE SHOWER',
#    'url': 'http://affordablegrowth.com',
#    'description': 'KILLED BY #ZODIAC. AM #GOD THE #ALIEN #JESUS. I LIKE PRETTY ROSES. #MAGA #TRUMPTEAM. #YELLOWTIP #MOAB HIDDEN TWEETS https://www.instagram.com/jkmimages/',
#    'translator_type': 'none',
#    'protected': False,
#    'verified': False,
#    'followers_count': 10,
#    'friends_count': 13,
#    'listed_count': 1,
#    'favourites_count': 7,
#    'statuses_count': 16180,
#    'created_at': 'Wed Feb 14 21:38:04 +0000 2018',
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'lang': 'en',
#    'contributors_enabled': False,
#    'is_translator': False,
#    'profile_background_color': 'F5F8FA',
#    'profile_background_image_url': '',
#    'profile_background_image_url_https': '',
#    'profile_background_tile': False,
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/963954830531162112/G2sZaTo0_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/963954830531162112/G2sZaTo0_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/963890107446067203/1524856691',
#    'default_profile': True,
#    'default_profile_image': False,
#    'following': None,
#    'follow_request_sent': None,
#    'notifications': None},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'is_quote_status': False,
#   'extended_tweet': {'full_text': 'BEING*\n\nAS IN MY #ALIEN LIFE. \n\n@RealDonaldTrump #NEWS #BREAKING #HOLLYWOOD #NYC #DC  @USAF_ACC  @FBI  @CIA @POTUS @FoxNews @infowars @BreitbartNews @DRUDGE_REPORT  @NEWS9  @BBC @NPR',
#    'display_text_range': [0, 182],
#    'entities': {'hashtags': [{'text': 'ALIEN', 'indices': [17, 23]},
#      {'text': 'NEWS', 'indices': [49, 54]},
#      {'text': 'BREAKING', 'indices': [55, 64]},
#      {'text': 'HOLLYWOOD', 'indices': [65, 75]},
#      {'text': 'NYC', 'indices': [76, 80]},
#      {'text': 'DC', 'indices': [81, 84]}],
#     'urls': [],
#     'user_mentions': [{'screen_name': 'realDonaldTrump',
#       'name': 'Donald J. Trump',
#       'id': 25073877,
#       'id_str': '25073877',
#       'indices': [32, 48]},
#      {'screen_name': 'USAF_ACC',
#       'name': 'Air Combat Command',
#       'id': 51039749,
#       'id_str': '51039749',
#       'indices': [86, 95]},
#      {'screen_name': 'FBI',
#       'name': 'FBI',
#       'id': 17629860,
#       'id_str': '17629860',
#       'indices': [97, 101]},
#      {'screen_name': 'CIA',
#       'name': 'CIA',
#       'id': 2359926157,
#       'id_str': '2359926157',
#       'indices': [103, 107]},
#      {'screen_name': 'POTUS',
#       'name': 'President Trump',
#       'id': 822215679726100480,
#       'id_str': '822215679726100480',
#       'indices': [108, 114]},
#      {'screen_name': 'FoxNews',
#       'name': 'Fox News',
#       'id': 1367531,
#       'id_str': '1367531',
#       'indices': [115, 123]},
#      {'screen_name': 'infowars',
#       'name': 'infowars',
#       'id': 14505245,
#       'id_str': '14505245',
#       'indices': [124, 133]},
#      {'screen_name': 'BreitbartNews',
#       'name': 'Breitbart News',
#       'id': 457984599,
#       'id_str': '457984599',
#       'indices': [134, 148]},
#      {'screen_name': 'DRUDGE_REPORT',
#       'name': 'DRUDGE REPORT',
#       'id': 14669951,
#       'id_str': '14669951',
#       'indices': [149, 163]},
#      {'screen_name': 'NEWS9',
#       'name': 'News 9',
#       'id': 15896162,
#       'id_str': '15896162',
#       'indices': [165, 171]},
#      {'screen_name': 'BBC',
#       'name': 'BBC',
#       'id': 19701628,
#       'id_str': '19701628',
#       'indices': [173, 177]},
#      {'screen_name': 'NPR',
#       'name': 'NPR',
#       'id': 5392522,
#       'id_str': '5392522',
#       'indices': [178, 182]}],
#     'symbols': []}},
#   'quote_count': 0,
#   'reply_count': 0,
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'entities': {'hashtags': [{'text': 'ALIEN', 'indices': [17, 23]},
#     {'text': 'NEWS', 'indices': [49, 54]},
#     {'text': 'BREAKING', 'indices': [55, 64]},
#     {'text': 'HOLLYWOOD', 'indices': [65, 75]},
#     {'text': 'NYC', 'indices': [76, 80]},
#     {'text': 'DC', 'indices': [81, 84]}],
#    'urls': [{'url': 'https://t.co/OqemH70Xnn',
#      'expanded_url': 'https://twitter.com/i/web/status/990979772368019457',
#      'display_url': 'twitter.com/i/web/status/9…',
#      'indices': [116, 139]}],
#    'user_mentions': [{'screen_name': 'realDonaldTrump',
#      'name': 'Donald J. Trump',
#      'id': 25073877,
#      'id_str': '25073877',
#      'indices': [32, 48]},
#     {'screen_name': 'USAF_ACC',
#      'name': 'Air Combat Command',
#      'id': 51039749,
#      'id_str': '51039749',
#      'indices': [86, 95]},
#     {'screen_name': 'FBI',
#      'name': 'FBI',
#      'id': 17629860,
#      'id_str': '17629860',
#      'indices': [97, 101]},
#     {'screen_name': 'CIA',
#      'name': 'CIA',
#      'id': 2359926157,
#      'id_str': '2359926157',
#      'indices': [103, 107]},
#     {'screen_name': 'POTUS',
#      'name': 'President Trump',
#      'id': 822215679726100480,
#      'id_str': '822215679726100480',
#      'indices': [108, 114]}],
#    'symbols': []},
#   'favorited': False,
#   'retweeted': False,
#   'filter_level': 'low',
#   'lang': 'en',
#   'timestamp_ms': '1525102963903'},
#  {'created_at': 'Mon Apr 30 15:42:46 +0000 2018',
#   'id': 990979781641596928,
#   'id_str': '990979781641596928',
#   'text': 'RT @TomFitton: .@RealDonaldTrump administration should deny entry to the mob of illegal aliens that seeks to challenge our sovereignty.  Le…',
#   'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   'truncated': False,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 2511520796,
#    'id_str': '2511520796',
#    'name': 'Tammy May',
#    'screen_name': 'Tambo4Freedom',
#    'location': 'America',
#    'url': None,
#    'description': 'I believe in God, Freedom, and the USA. We are a Constitutional Republic and, by God, we are going to keep it that way! #MAGA \nfollowed by @GenFlynn',
#    'translator_type': 'none',
#    'protected': False,
#    'verified': False,
#    'followers_count': 5235,
#    'friends_count': 5109,
#    'listed_count': 31,
#    'favourites_count': 161067,
#    'statuses_count': 64079,
#    'created_at': 'Wed May 21 01:10:47 +0000 2014',
#    'utc_offset': -25200,
#    'time_zone': 'Pacific Time (US & Canada)',
#    'geo_enabled': False,
#    'lang': 'en',
#    'contributors_enabled': False,
#    'is_translator': False,
#    'profile_background_color': '000000',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_link_color': '1B95E0',
#    'profile_sidebar_border_color': '000000',
#    'profile_sidebar_fill_color': '000000',
#    'profile_text_color': '000000',
#    'profile_use_background_image': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/883912794307002369/y4zhoVP8_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/883912794307002369/y4zhoVP8_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/2511520796/1499576484',
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': None,
#    'follow_request_sent': None,
#    'notifications': None},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'retweeted_status': {'created_at': 'Mon Apr 30 12:06:26 +0000 2018',
#    'id': 990925342788521985,
#    'id_str': '990925342788521985',
#    'text': '.@RealDonaldTrump administration should deny entry to the mob of illegal aliens that seeks to challenge our soverei… https://t.co/w7Xb1LdrSQ',
#    'source': '<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>',
#    'truncated': True,
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 18266688,
#     'id_str': '18266688',
#     'name': 'Tom Fitton',
#     'screen_name': 'TomFitton',
#     'location': 'Washington, DC',
#     'url': 'http://www.JudicialWatch.org',
#     'description': 'President, Judicial Watch. (These are my personal views only!)  Author of New York Times best seller Clean House. http://amzn.com/1501137042',
#     'translator_type': 'regular',
#     'protected': False,
#     'verified': True,
#     'followers_count': 248093,
#     'friends_count': 2766,
#     'listed_count': 1416,
#     'favourites_count': 247,
#     'statuses_count': 17282,
#     'created_at': 'Sat Dec 20 14:32:44 +0000 2008',
#     'utc_offset': -14400,
#     'time_zone': 'America/New_York',
#     'geo_enabled': False,
#     'lang': 'en',
#     'contributors_enabled': False,
#     'is_translator': False,
#     'profile_background_color': '568448',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme4/bg.gif',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme4/bg.gif',
#     'profile_background_tile': False,
#     'profile_link_color': '1B95E0',
#     'profile_sidebar_border_color': 'FFFFFF',
#     'profile_sidebar_fill_color': 'ECD295',
#     'profile_text_color': '3C3940',
#     'profile_use_background_image': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/964235516794171392/ktAX5u2i_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/964235516794171392/ktAX5u2i_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/18266688/1473875094',
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': None,
#     'follow_request_sent': None,
#     'notifications': None},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'extended_tweet': {'full_text': '.@RealDonaldTrump administration should deny entry to the mob of illegal aliens that seeks to challenge our sovereignty.  Legitimate asylum seekers can request asylum at U.S. consulates in Mexico -- and wait there. Or detain each and every one until claims are sorted out.',
#     'display_text_range': [0, 272],
#     'entities': {'hashtags': [],
#      'urls': [],
#      'user_mentions': [{'screen_name': 'realDonaldTrump',
#        'name': 'Donald J. Trump',
#        'id': 25073877,
#        'id_str': '25073877',
#        'indices': [1, 17]}],
#      'symbols': []}},
#    'quote_count': 124,
#    'reply_count': 229,
#    'retweet_count': 2177,
#    'favorite_count': 4896,
#    'entities': {'hashtags': [],
#     'urls': [{'url': 'https://t.co/w7Xb1LdrSQ',
#       'expanded_url': 'https://twitter.com/i/web/status/990925342788521985',
#       'display_url': 'twitter.com/i/web/status/9…',
#       'indices': [117, 140]}],
#     'user_mentions': [{'screen_name': 'realDonaldTrump',
#       'name': 'Donald J. Trump',
#       'id': 25073877,
#       'id_str': '25073877',
#       'indices': [1, 17]}],
#     'symbols': []},
#    'favorited': False,
#    'retweeted': False,
#    'filter_level': 'low',
#    'lang': 'en'},
#   'is_quote_status': False,
#   'quote_count': 0,
#   'reply_count': 0,
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'entities': {'hashtags': [],
#    'urls': [],
#    'user_mentions': [{'screen_name': 'TomFitton',
#      'name': 'Tom Fitton',
#      'id': 18266688,
#      'id_str': '18266688',
#      'indices': [3, 13]},
#     {'screen_name': 'realDonaldTrump',
#      'name': 'Donald J. Trump',
#      'id': 25073877,
#      'id_str': '25073877',
#      'indices': [16, 32]}],
#    'symbols': []},
#   'favorited': False,
#   'retweeted': False,
#   'filter_level': 'low',
#   'lang': 'en',
#   'timestamp_ms': '1525102966114'},
#  {'created_at': 'Mon Apr 30 15:42:46 +0000 2018',
#   'id': 990979782908129280,
#   'id_str': '990979782908129280',
#   'text': 'RT @13jake13love: For the record, and on the record, I, Neeru Bey, am a walking, talking, independent island mortal man and a living spirit…',
#   'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#   'truncated': False,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 2904699857,
#    'id_str': '2904699857',
#    'name': 'Anu-Adsila Bey13 TM',
#    'screen_name': 'seeinginfull',
#    'location': 'Area - Portland, Oregon',
#    'url': None,
#    'description': 'I AM a Seeker & Nobody tells me Truth like Da13thSun.  I Love♡Nature. I Am A Child of The Most Highs. I am down to earth and devinely connected. 13 Love♡',
#    'translator_type': 'none',
#    'protected': False,
#    'verified': False,
#    'followers_count': 1120,
#    'friends_count': 926,
#    'listed_count': 79,
#    'favourites_count': 225412,
#    'statuses_count': 200232,
#    'created_at': 'Thu Dec 04 04:58:31 +0000 2014',
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': True,
#    'lang': 'en',
#    'contributors_enabled': False,
#    'is_translator': False,
#    'profile_background_color': 'C0DEED',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/921119120564695040/NPgdnmgs_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/921119120564695040/NPgdnmgs_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/2904699857/1470362559',
#    'default_profile': True,
#    'default_profile_image': False,
#    'following': None,
#    'follow_request_sent': None,
#    'notifications': None},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'retweeted_status': {'created_at': 'Mon Apr 30 15:11:04 +0000 2018',
#    'id': 990971804922667008,
#    'id_str': '990971804922667008',
#    'text': 'For the record, and on the record, I, Neeru Bey, am a walking, talking, independent island mortal man and a living… https://t.co/upAMj5UzAP',
#    'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#    'truncated': True,
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 717818321719136256,
#     'id_str': '717818321719136256',
#     'name': '13Neeru Bey™',
#     'screen_name': '13jake13love',
#     'location': 'Amazing Mother Earth',
#     'url': None,
#     'description': 'I AM ME 13 Child of THE MOST HIGHS   Learning humbly to be pure, righteous, and free. 13love TLC',
#     'translator_type': 'none',
#     'protected': False,
#     'verified': False,
#     'followers_count': 313,
#     'friends_count': 113,
#     'listed_count': 0,
#     'favourites_count': 1101,
#     'statuses_count': 741,
#     'created_at': 'Wed Apr 06 20:56:39 +0000 2016',
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'lang': 'en',
#     'contributors_enabled': False,
#     'is_translator': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': '',
#     'profile_background_image_url_https': '',
#     'profile_background_tile': False,
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/750827179538321408/DtVGEcNT_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/750827179538321408/DtVGEcNT_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/717818321719136256/1461976134',
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': None,
#     'follow_request_sent': None,
#     'notifications': None},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'extended_tweet': {'full_text': 'For the record, and on the record, I, Neeru Bey, am a walking, talking, independent island mortal man and a living spirit. I am created in the image of Hashem.\xa0I am a true Moor. I am not a resident Alien, and I am foreign to the U.S.',
#     'display_text_range': [0, 233],
#     'entities': {'hashtags': [],
#      'urls': [],
#      'user_mentions': [],
#      'symbols': []}},
#    'quote_count': 0,
#    'reply_count': 0,
#    'retweet_count': 4,
#    'favorite_count': 3,
#    'entities': {'hashtags': [],
#     'urls': [{'url': 'https://t.co/upAMj5UzAP',
#       'expanded_url': 'https://twitter.com/i/web/status/990971804922667008',
#       'display_url': 'twitter.com/i/web/status/9…',
#       'indices': [116, 139]}],
#     'user_mentions': [],
#     'symbols': []},
#    'favorited': False,
#    'retweeted': False,
#    'filter_level': 'low',
#    'lang': 'en'},
#   'is_quote_status': False,
#   'quote_count': 0,
#   'reply_count': 0,
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'entities': {'hashtags': [],
#    'urls': [],
#    'user_mentions': [{'screen_name': '13jake13love',
#      'name': '13Neeru Bey™',
#      'id': 717818321719136256,
#      'id_str': '717818321719136256',
#      'indices': [3, 16]}],
#    'symbols': []},
#   'favorited': False,
#   'retweeted': False,
#   'filter_level': 'low',
#   'lang': 'en',
#   'timestamp_ms': '1525102966416'},
#  {'created_at': 'Mon Apr 30 15:42:47 +0000 2018',
#   'id': 990979788167761921,
#   'id_str': '990979788167761921',
#   'text': 'RT @SiddonsDan: “It’s a damn shame when the President of the United States and it’s citizens complain about the influx of illegal aliens in…',
#   'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#   'truncated': False,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 103913011,
#    'id_str': '103913011',
#    'name': 'LisaJane 🇺🇸🇺🇸👠',
#    'screen_name': 'libasiba',
#    'location': None,
#    'url': None,
#    'description': "RELEASE THE TEXTS !!! I am so proud of our president and The MAGA movement. American's are DREAMERS TOO !!! Follow Q\n#KATESWALL \n#Codeofvets \n#Redpill",
#    'translator_type': 'none',
#    'protected': False,
#    'verified': False,
#    'followers_count': 4920,
#    'friends_count': 5138,
#    'listed_count': 3,
#    'favourites_count': 40026,
#    'statuses_count': 37202,
#    'created_at': 'Mon Jan 11 17:18:48 +0000 2010',
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': True,
#    'lang': 'en',
#    'contributors_enabled': False,
#    'is_translator': False,
#    'profile_background_color': 'C0DEED',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/966752449141776384/LSP9JdD-_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/966752449141776384/LSP9JdD-_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/103913011/1519654517',
#    'default_profile': True,
#    'default_profile_image': False,
#    'following': None,
#    'follow_request_sent': None,
#    'notifications': None},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'retweeted_status': {'created_at': 'Sun Apr 29 13:30:44 +0000 2018',
#    'id': 990584166591889409,
#    'id_str': '990584166591889409',
#    'text': '“It’s a damn shame when the President of the United States and it’s citizens complain about the influx of illegal a… https://t.co/VPo3O1JkMa',
#    'display_text_range': [0, 140],
#    'source': '<a href="http://twitter.com/#!/download/ipad" rel="nofollow">Twitter for iPad</a>',
#    'truncated': True,
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 867947619661881344,
#     'id_str': '867947619661881344',
#     'name': 'Dan Siddons',
#     'screen_name': 'SiddonsDan',
#     'location': None,
#     'url': 'http://WayneDupree.com',
#     'description': '@trish_regan @ericbolling @katrinapierson @RealJamesWoods @michellemalkin @RealDrGina @DLoesch @WayneDupreeShow @conservmillen @Tell_Michelle_ @deneenborelli',
#     'translator_type': 'none',
#     'protected': False,
#     'verified': False,
#     'followers_count': 74688,
#     'friends_count': 74614,
#     'listed_count': 222,
#     'favourites_count': 177378,
#     'statuses_count': 221827,
#     'created_at': 'Fri May 26 03:36:53 +0000 2017',
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': True,
#     'lang': 'en',
#     'contributors_enabled': False,
#     'is_translator': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': '',
#     'profile_background_image_url_https': '',
#     'profile_background_tile': False,
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/932133290194165760/gKVRr-xH_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/932133290194165760/gKVRr-xH_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/867947619661881344/1524935474',
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': None,
#     'follow_request_sent': None,
#     'notifications': None},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'extended_tweet': {'full_text': '“It’s a damn shame when the President of the United States and it’s citizens complain about the influx of illegal aliens invading our nation... \nwhile the legacy media, Democrats, some Republicans turn their heads and lie that we’re all against immigration.”~@WayneDupreeShow https://t.co/6nobbq0bOu',
#     'display_text_range': [0, 275],
#     'entities': {'hashtags': [],
#      'urls': [],
#      'user_mentions': [{'screen_name': 'WayneDupreeShow',
#        'name': '🎙Wayne Dupree',
#        'id': 282695161,
#        'id_str': '282695161',
#        'indices': [259, 275]}],
#      'symbols': [],
#      'media': [{'id': 990584153358790657,
#        'id_str': '990584153358790657',
#        'indices': [276, 299],
#        'media_url': 'http://pbs.twimg.com/media/Db9DCgUU8AExmEa.jpg',
#        'media_url_https': 'https://pbs.twimg.com/media/Db9DCgUU8AExmEa.jpg',
#        'url': 'https://t.co/6nobbq0bOu',
#        'display_url': 'pic.twitter.com/6nobbq0bOu',
#        'expanded_url': 'https://twitter.com/SiddonsDan/status/990584166591889409/photo/1',
#        'type': 'photo',
#        'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#         'medium': {'w': 595, 'h': 316, 'resize': 'fit'},
#         'small': {'w': 595, 'h': 316, 'resize': 'fit'},
#         'large': {'w': 595, 'h': 316, 'resize': 'fit'}}}]},
#     'extended_entities': {'media': [{'id': 990584153358790657,
#        'id_str': '990584153358790657',
#        'indices': [276, 299],
#        'media_url': 'http://pbs.twimg.com/media/Db9DCgUU8AExmEa.jpg',
#        'media_url_https': 'https://pbs.twimg.com/media/Db9DCgUU8AExmEa.jpg',
#        'url': 'https://t.co/6nobbq0bOu',
#        'display_url': 'pic.twitter.com/6nobbq0bOu',
#        'expanded_url': 'https://twitter.com/SiddonsDan/status/990584166591889409/photo/1',
#        'type': 'photo',
#        'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#         'medium': {'w': 595, 'h': 316, 'resize': 'fit'},
#         'small': {'w': 595, 'h': 316, 'resize': 'fit'},
#         'large': {'w': 595, 'h': 316, 'resize': 'fit'}}}]}},
#    'quote_count': 3,
#    'reply_count': 18,
#    'retweet_count': 347,
#    'favorite_count': 441,
#    'entities': {'hashtags': [],
#     'urls': [{'url': 'https://t.co/VPo3O1JkMa',
#       'expanded_url': 'https://twitter.com/i/web/status/990584166591889409',
#       'display_url': 'twitter.com/i/web/status/9…',
#       'indices': [117, 140]}],
#     'user_mentions': [],
#     'symbols': []},
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': True,
#    'filter_level': 'low',
#    'lang': 'en'},
#   'is_quote_status': False,
#   'quote_count': 0,
#   'reply_count': 0,
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'entities': {'hashtags': [],
#    'urls': [],
#    'user_mentions': [{'screen_name': 'SiddonsDan',
#      'name': 'Dan Siddons',
#      'id': 867947619661881344,
#      'id_str': '867947619661881344',
#      'indices': [3, 14]}],
#    'symbols': []},
#   'favorited': False,
#   'retweeted': False,
#   'filter_level': 'low',
#   'lang': 'en',
#   'timestamp_ms': '1525102967670'},
#  {'created_at': 'Mon Apr 30 15:42:48 +0000 2018',
#   'id': 990979791212851205,
#   'id_str': '990979791212851205',
#   'text': "@dekdarion It's getting closer and closer. Very soon Dr. Steven Greer or David Wilcock will appear out of nowhere t… https://t.co/yQJzc8d0ff",
#   'display_text_range': [11, 140],
#   'source': '<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>',
#   'truncated': True,
#   'in_reply_to_status_id': 990977602926989314,
#   'in_reply_to_status_id_str': '990977602926989314',
#   'in_reply_to_user_id': 786429886747463680,
#   'in_reply_to_user_id_str': '786429886747463680',
#   'in_reply_to_screen_name': 'FerGucci2008',
#   'user': {'id': 786429886747463680,
#    'id_str': '786429886747463680',
#    'name': 'O-9-Team',
#    'screen_name': 'FerGucci2008',
#    'location': 'Los Angeles, CA',
#    'url': None,
#    'description': 'IntraNet-Specialist-ORACLE-SQL',
#    'translator_type': 'none',
#    'protected': False,
#    'verified': False,
#    'followers_count': 2300,
#    'friends_count': 4832,
#    'listed_count': 12,
#    'favourites_count': 17292,
#    'statuses_count': 12741,
#    'created_at': 'Thu Oct 13 04:54:30 +0000 2016',
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'lang': 'en',
#    'contributors_enabled': False,
#    'is_translator': False,
#    'profile_background_color': 'F5F8FA',
#    'profile_background_image_url': '',
#    'profile_background_image_url_https': '',
#    'profile_background_tile': False,
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/978800078839193600/bhAjkApb_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/978800078839193600/bhAjkApb_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/786429886747463680/1523165942',
#    'default_profile': True,
#    'default_profile_image': False,
#    'following': None,
#    'follow_request_sent': None,
#    'notifications': None},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'is_quote_status': False,
#   'extended_tweet': {'full_text': "@dekdarion It's getting closer and closer. Very soon Dr. Steven Greer or David Wilcock will appear out of nowhere to make a claim that the WORLD is now ready for an ALIEN ARRIVAL DISCLOSURE!!!",
#    'display_text_range': [11, 192],
#    'entities': {'hashtags': [],
#     'urls': [],
#     'user_mentions': [{'screen_name': 'dekdarion',
#       'name': '#QAnon gab.ai/dekdarion',
#       'id': 792374882654834689,
#       'id_str': '792374882654834689',
#       'indices': [0, 10]}],
#     'symbols': []}},
#   'quote_count': 0,
#   'reply_count': 0,
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'entities': {'hashtags': [],
#    'urls': [{'url': 'https://t.co/yQJzc8d0ff',
#      'expanded_url': 'https://twitter.com/i/web/status/990979791212851205',
#      'display_url': 'twitter.com/i/web/status/9…',
#      'indices': [117, 140]}],
#    'user_mentions': [{'screen_name': 'dekdarion',
#      'name': '#QAnon gab.ai/dekdarion',
#      'id': 792374882654834689,
#      'id_str': '792374882654834689',
#      'indices': [0, 10]}],
#    'symbols': []},
#   'favorited': False,
#   'retweeted': False,
#   'filter_level': 'low',
#   'lang': 'en',
#   'timestamp_ms': '1525102968396'},
#  {'created_at': 'Mon Apr 30 15:42:49 +0000 2018',
#   'id': 990979795084283904,
#   'id_str': '990979795084283904',
#   'text': 'RT @jonnybrenns: although i am TRiGgeReD tweeting about american idol, ill make the sacrifice for @hashtagcatie and @calebleemusic ; VOTE F…',
#   'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   'truncated': False,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 987198549942251520,
#    'id_str': '987198549942251520',
#    'name': 'madelyn',
#    'screen_name': 'madelyn34727650',
#    'location': None,
#    'url': None,
#    'description': None,
#    'translator_type': 'none',
#    'protected': False,
#    'verified': False,
#    'followers_count': 16,
#    'friends_count': 48,
#    'listed_count': 0,
#    'favourites_count': 215,
#    'statuses_count': 41,
#    'created_at': 'Fri Apr 20 05:17:30 +0000 2018',
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'lang': 'en',
#    'contributors_enabled': False,
#    'is_translator': False,
#    'profile_background_color': 'F5F8FA',
#    'profile_background_image_url': '',
#    'profile_background_image_url_https': '',
#    'profile_background_tile': False,
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'profile_image_url': 'http://abs.twimg.com/sticky/default_profile_images/default_profile_normal.png',
#    'profile_image_url_https': 'https://abs.twimg.com/sticky/default_profile_images/default_profile_normal.png',
#    'default_profile': True,
#    'default_profile_image': False,
#    'following': None,
#    'follow_request_sent': None,
#    'notifications': None},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'retweeted_status': {'created_at': 'Sun Apr 29 19:25:22 +0000 2018',
#    'id': 990673413802020865,
#    'id_str': '990673413802020865',
#    'text': 'although i am TRiGgeReD tweeting about american idol, ill make the sacrifice for @hashtagcatie and @calebleemusic ;… https://t.co/mHWC4C3RQ5',
#    'source': '<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>',
#    'truncated': True,
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 3068988173,
#     'id_str': '3068988173',
#     'name': 'jonny b',
#     'screen_name': 'jonnybrenns',
#     'location': 'St Augustine Beach, FL',
#     'url': 'https://open.spotify.com/artist/3mUGTspyqcV2t0fJR5kPFG?si=Z_aE6_3nQqCTXDckQg9igA',
#     'description': 'top 14 on season 1 of american idol. snapchat and instagram: jonnybrenns. \nEP ALBUM LINK BELOW',
#     'translator_type': 'none',
#     'protected': False,
#     'verified': True,
#     'followers_count': 15872,
#     'friends_count': 73,
#     'listed_count': 41,
#     'favourites_count': 3411,
#     'statuses_count': 543,
#     'created_at': 'Wed Mar 04 01:06:26 +0000 2015',
#     'utc_offset': -25200,
#     'time_zone': 'Pacific Time (US & Canada)',
#     'geo_enabled': True,
#     'lang': 'en',
#     'contributors_enabled': False,
#     'is_translator': False,
#     'profile_background_color': '000000',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_link_color': 'ABB8C2',
#     'profile_sidebar_border_color': '000000',
#     'profile_sidebar_fill_color': '000000',
#     'profile_text_color': '000000',
#     'profile_use_background_image': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/966590013407285248/Dl_lsQYh_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/966590013407285248/Dl_lsQYh_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/3068988173/1525060143',
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': None,
#     'follow_request_sent': None,
#     'notifications': None},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'extended_tweet': {'full_text': 'although i am TRiGgeReD tweeting about american idol, ill make the sacrifice for @hashtagcatie and @calebleemusic ; VOTE FOR THE MARTIAN AND COWBOY!',
#     'display_text_range': [0, 148],
#     'entities': {'hashtags': [],
#      'urls': [],
#      'user_mentions': [{'screen_name': 'hashtagcatie',
#        'name': 'catie turner',
#        'id': 2298761174,
#        'id_str': '2298761174',
#        'indices': [81, 94]},
#       {'screen_name': 'calebleemusic',
#        'name': 'Caleb Lee Hutchinson',
#        'id': 2928756501,
#        'id_str': '2928756501',
#        'indices': [99, 113]}],
#      'symbols': []}},
#    'quote_count': 3,
#    'reply_count': 33,
#    'retweet_count': 81,
#    'favorite_count': 773,
#    'entities': {'hashtags': [],
#     'urls': [{'url': 'https://t.co/mHWC4C3RQ5',
#       'expanded_url': 'https://twitter.com/i/web/status/990673413802020865',
#       'display_url': 'twitter.com/i/web/status/9…',
#       'indices': [117, 140]}],
#     'user_mentions': [{'screen_name': 'hashtagcatie',
#       'name': 'catie turner',
#       'id': 2298761174,
#       'id_str': '2298761174',
#       'indices': [81, 94]},
#      {'screen_name': 'calebleemusic',
#       'name': 'Caleb Lee Hutchinson',
#       'id': 2928756501,
#       'id_str': '2928756501',
#       'indices': [99, 113]}],
#     'symbols': []},
#    'favorited': False,
#    'retweeted': False,
#    'filter_level': 'low',
#    'lang': 'en'},
#   'is_quote_status': False,
#   'quote_count': 0,
#   'reply_count': 0,
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'entities': {'hashtags': [],
#    'urls': [],
#    'user_mentions': [{'screen_name': 'jonnybrenns',
#      'name': 'jonny b',
#      'id': 3068988173,
#      'id_str': '3068988173',
#      'indices': [3, 15]},
#     {'screen_name': 'hashtagcatie',
#      'name': 'catie turner',
#      'id': 2298761174,
#      'id_str': '2298761174',
#      'indices': [98, 111]},
#     {'screen_name': 'calebleemusic',
#      'name': 'Caleb Lee Hutchinson',
#      'id': 2928756501,
#      'id_str': '2928756501',
#      'indices': [116, 130]}],
#    'symbols': []},
#   'favorited': False,
#   'retweeted': False,
#   'filter_level': 'low',
#   'lang': 'en',
#   'timestamp_ms': '1525102969319'},
#  {'created_at': 'Mon Apr 30 15:42:50 +0000 2018',
#   'id': 990979801619058688,
#   'id_str': '990979801619058688',
#   'text': 'RT @FoxNews: Hector Garza: "We\'re catching a lot of criminal aliens. Those criminal aliens are aliens that have criminal records in the Uni…',
#   'source': '<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>',
#   'truncated': False,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 173119648,
#    'id_str': '173119648',
#    'name': 'Cathy Webb',
#    'screen_name': 'lifecoachcathy',
#    'location': None,
#    'url': None,
#    'description': "Cathy's coaching and  presentations have ignited the spark of creativity and inspired action in audiences of all ages! Speaker and author, lover of life.",
#    'translator_type': 'none',
#    'protected': False,
#    'verified': False,
#    'followers_count': 4327,
#    'friends_count': 5002,
#    'listed_count': 448,
#    'favourites_count': 47102,
#    'statuses_count': 174897,
#    'created_at': 'Sat Jul 31 13:53:16 +0000 2010',
#    'utc_offset': -14400,
#    'time_zone': 'Eastern Time (US & Canada)',
#    'geo_enabled': False,
#    'lang': 'en',
#    'contributors_enabled': False,
#    'is_translator': False,
#    'profile_background_color': 'FFFFFF',
#    'profile_background_image_url': 'http://pbs.twimg.com/profile_background_images/143199299/beach.jpg',
#    'profile_background_image_url_https': 'https://pbs.twimg.com/profile_background_images/143199299/beach.jpg',
#    'profile_background_tile': False,
#    'profile_link_color': '0084B4',
#    'profile_sidebar_border_color': '135B99',
#    'profile_sidebar_fill_color': 'AFD8FB',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1092304955/lifecoach_Cathy_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1092304955/lifecoach_Cathy_normal.jpg',
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': None,
#    'follow_request_sent': None,
#    'notifications': None},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'retweeted_status': {'created_at': 'Mon Apr 30 05:44:00 +0000 2018',
#    'id': 990829097889693696,
#    'id_str': '990829097889693696',
#    'text': 'Hector Garza: "We\'re catching a lot of criminal aliens. Those criminal aliens are aliens that have criminal records… https://t.co/Wy8xwb0kPa',
#    'display_text_range': [0, 140],
#    'source': '<a href="https://studio.twitter.com" rel="nofollow">Media Studio</a>',
#    'truncated': True,
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 1367531,
#     'id_str': '1367531',
#     'name': 'Fox News',
#     'screen_name': 'FoxNews',
#     'location': 'U.S.A.',
#     'url': 'http://www.foxnews.com',
#     'description': "America’s Strongest Primetime Lineup Anywhere! Follow America's #1 cable news network, delivering you breaking news, insightful analysis, and must-see videos.",
#     'translator_type': 'regular',
#     'protected': False,
#     'verified': True,
#     'followers_count': 17816323,
#     'friends_count': 408,
#     'listed_count': 63262,
#     'favourites_count': 0,
#     'statuses_count': 378604,
#     'created_at': 'Sat Mar 17 19:01:26 +0000 2007',
#     'utc_offset': -14400,
#     'time_zone': 'Eastern Time (US & Canada)',
#     'geo_enabled': False,
#     'lang': 'en',
#     'contributors_enabled': False,
#     'is_translator': False,
#     'profile_background_color': '0E2331',
#     'profile_background_image_url': 'http://pbs.twimg.com/profile_background_images/414488415/xyz123abc.jpg',
#     'profile_background_image_url_https': 'https://pbs.twimg.com/profile_background_images/414488415/xyz123abc.jpg',
#     'profile_background_tile': False,
#     'profile_link_color': '183A52',
#     'profile_sidebar_border_color': 'FFFFFF',
#     'profile_sidebar_fill_color': 'F4F4F4',
#     'profile_text_color': '000000',
#     'profile_use_background_image': True,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/918480715158716419/4X8oCbge_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/918480715158716419/4X8oCbge_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1367531/1492649996',
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': None,
#     'follow_request_sent': None,
#     'notifications': None},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'extended_tweet': {'full_text': 'Hector Garza: "We\'re catching a lot of criminal aliens. Those criminal aliens are aliens that have criminal records in the United States. They\'re murderers, they\'re rapists, they\'re child predators... We need to build that wall so we can save American lives." https://t.co/SAXVOOelHk',
#     'display_text_range': [0, 259],
#     'entities': {'hashtags': [],
#      'urls': [],
#      'user_mentions': [],
#      'symbols': [],
#      'media': [{'id': 990629729924534272,
#        'id_str': '990629729924534272',
#        'indices': [260, 283],
#        'additional_media_info': {'title': '',
#         'description': '',
#         'embeddable': True,
#         'monetizable': False},
#        'media_url': 'http://pbs.twimg.com/media/Db9sxGvXkAIkvFC.jpg',
#        'media_url_https': 'https://pbs.twimg.com/media/Db9sxGvXkAIkvFC.jpg',
#        'url': 'https://t.co/SAXVOOelHk',
#        'display_url': 'pic.twitter.com/SAXVOOelHk',
#        'expanded_url': 'https://twitter.com/FoxNews/status/990829097889693696/video/1',
#        'type': 'video',
#        'video_info': {'aspect_ratio': [16, 9],
#         'duration_millis': 240855,
#         'variants': [{'bitrate': 2176000,
#           'content_type': 'video/mp4',
#           'url': 'https://video.twimg.com/amplify_video/990629729924534272/vid/1280x720/txl0HpbxXWTT63eJ.mp4?tag=2'},
#          {'bitrate': 832000,
#           'content_type': 'video/mp4',
#           'url': 'https://video.twimg.com/amplify_video/990629729924534272/vid/640x360/WUDDq2xc5Zc1DN8Q.mp4?tag=2'},
#          {'content_type': 'application/x-mpegURL',
#           'url': 'https://video.twimg.com/amplify_video/990629729924534272/pl/UfxyGrpGS6k6Gini.m3u8?tag=2'},
#          {'bitrate': 320000,
#           'content_type': 'video/mp4',
#           'url': 'https://video.twimg.com/amplify_video/990629729924534272/vid/320x180/N71mpTfBKaMDm5Y_.mp4?tag=2'}]},
#        'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#         'medium': {'w': 1200, 'h': 675, 'resize': 'fit'},
#         'small': {'w': 680, 'h': 383, 'resize': 'fit'},
#         'large': {'w': 1280, 'h': 720, 'resize': 'fit'}}}]},
#     'extended_entities': {'media': [{'id': 990629729924534272,
#        'id_str': '990629729924534272',
#        'indices': [260, 283],
#        'additional_media_info': {'title': '',
#         'description': '',
#         'embeddable': True,
#         'monetizable': False},
#        'media_url': 'http://pbs.twimg.com/media/Db9sxGvXkAIkvFC.jpg',
#        'media_url_https': 'https://pbs.twimg.com/media/Db9sxGvXkAIkvFC.jpg',
#        'url': 'https://t.co/SAXVOOelHk',
#        'display_url': 'pic.twitter.com/SAXVOOelHk',
#        'expanded_url': 'https://twitter.com/FoxNews/status/990829097889693696/video/1',
#        'type': 'video',
#        'video_info': {'aspect_ratio': [16, 9],
#         'duration_millis': 240855,
#         'variants': [{'bitrate': 2176000,
#           'content_type': 'video/mp4',
#           'url': 'https://video.twimg.com/amplify_video/990629729924534272/vid/1280x720/txl0HpbxXWTT63eJ.mp4?tag=2'},
#          {'bitrate': 832000,
#           'content_type': 'video/mp4',
#           'url': 'https://video.twimg.com/amplify_video/990629729924534272/vid/640x360/WUDDq2xc5Zc1DN8Q.mp4?tag=2'},
#          {'content_type': 'application/x-mpegURL',
#           'url': 'https://video.twimg.com/amplify_video/990629729924534272/pl/UfxyGrpGS6k6Gini.m3u8?tag=2'},
#          {'bitrate': 320000,
#           'content_type': 'video/mp4',
#           'url': 'https://video.twimg.com/amplify_video/990629729924534272/vid/320x180/N71mpTfBKaMDm5Y_.mp4?tag=2'}]},
#        'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#         'medium': {'w': 1200, 'h': 675, 'resize': 'fit'},
#         'small': {'w': 680, 'h': 383, 'resize': 'fit'},
#         'large': {'w': 1280, 'h': 720, 'resize': 'fit'}}}]}},
#    'quote_count': 20,
#    'reply_count': 137,
#    'retweet_count': 249,
#    'favorite_count': 761,
#    'entities': {'hashtags': [],
# ...
#       'indices': [117, 140]}],
#     'user_mentions': [],
#     'symbols': []},
#    'favorited': False,
#    'retweeted': False,
#    'filter_level': 'low',
#    'lang': 'en'},
#   'is_quote_status': False,
#   'quote_count': 0,
#   'reply_count': 0,
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'entities': {'hashtags': [],
#    'urls': [],
#    'user_mentions': [{'screen_name': 'Thom44810402',
#      'name': 'Thom',
#      'id': 850065940305895424,
#      'id_str': '850065940305895424',
#      'indices': [3, 16]}],
#    'symbols': []},
#   'favorited': False,
#   'retweeted': False,
#   'filter_level': 'low',
#   'lang': 'en',
#   'timestamp_ms': '1525102977181'},
#  {'created_at': 'Mon Apr 30 15:42:58 +0000 2018',
#   'id': 990979831524397058,
#   'id_str': '990979831524397058',
#   'text': "RT @therealcbrad: look here's the situation: i already sit on the floor and think about what counts as 'natural' and that aliens would cons…",
#   'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#   'truncated': False,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 1070204256,
#    'id_str': '1070204256',
#    'name': 'FLOOR BABA ⛳',
#    'screen_name': 'FLOOR_BABA',
#    'location': None,
#    'url': 'https://www.floorbaba.zone/',
#    'description': 'designer and producer boy. also do some things @DESKPOPmusic @bluelighttapes',
#    'translator_type': 'none',
#    'protected': False,
#    'verified': False,
#    'followers_count': 2747,
#    'friends_count': 1291,
#    'listed_count': 61,
#    'favourites_count': 41974,
#    'statuses_count': 32888,
#    'created_at': 'Tue Jan 08 07:12:20 +0000 2013',
#    'utc_offset': -14400,
#    'time_zone': 'Eastern Time (US & Canada)',
#    'geo_enabled': True,
#    'lang': 'en',
#    'contributors_enabled': False,
#    'is_translator': False,
#    'profile_background_color': '6D6B91',
#    'profile_background_image_url': 'http://pbs.twimg.com/profile_background_images/564096713351114752/nyHan279.png',
#    'profile_background_image_url_https': 'https://pbs.twimg.com/profile_background_images/564096713351114752/nyHan279.png',
#    'profile_background_tile': True,
#    'profile_link_color': '981CEB',
#    'profile_sidebar_border_color': 'FFFFFF',
#    'profile_sidebar_fill_color': '669F98',
#    'profile_text_color': '79A79D',
#    'profile_use_background_image': True,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/987330599399587841/bmyTcbUJ_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/987330599399587841/bmyTcbUJ_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1070204256/1524198796',
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': None,
#    'follow_request_sent': None,
#    'notifications': None},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'retweeted_status': {'created_at': 'Mon Apr 30 15:27:24 +0000 2018',
#    'id': 990975916506603521,
#    'id_str': '990975916506603521',
#    'text': "look here's the situation: i already sit on the floor and think about what counts as 'natural' and that aliens woul… https://t.co/atcHUcyXRm",
#    'source': '<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>',
#    'truncated': True,
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 1692592524,
#     'id_str': '1692592524',
#     'name': 'therealcnothing',
#     'screen_name': 'therealcbrad',
#     'location': 'Bed',
#     'url': None,
#     'description': 'peanut butter la croix😋',
#     'translator_type': 'none',
#     'protected': False,
#     'verified': False,
#     'followers_count': 2853,
#     'friends_count': 920,
#     'listed_count': 43,
#     'favourites_count': 100102,
#     'statuses_count': 29628,
#     'created_at': 'Fri Aug 23 02:11:26 +0000 2013',
#     'utc_offset': -25200,
#     'time_zone': 'Pacific Time (US & Canada)',
#     'geo_enabled': False,
#     'lang': 'en',
#     'contributors_enabled': False,
#     'is_translator': False,
#     'profile_background_color': '000000',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_link_color': 'F58EA8',
#     'profile_sidebar_border_color': '000000',
#     'profile_sidebar_fill_color': '000000',
#     'profile_text_color': '000000',
#     'profile_use_background_image': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/932040587498442753/PsaYfvax_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/932040587498442753/PsaYfvax_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1692592524/1503109823',
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': None,
#     'follow_request_sent': None,
#     'notifications': None},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'extended_tweet': {'full_text': "look here's the situation: i already sit on the floor and think about what counts as 'natural' and that aliens would consider all our tech junk and space detritus to be by products of us, an animal species, like we think of beehives\n\nso it's best for me to be sober",
#     'display_text_range': [0, 265],
#     'entities': {'hashtags': [],
#      'urls': [],
#      'user_mentions': [],
#      'symbols': []}},
#    'quote_count': 0,
#    'reply_count': 0,
#    'retweet_count': 2,
#    'favorite_count': 20,
#    'entities': {'hashtags': [],
#     'urls': [{'url': 'https://t.co/atcHUcyXRm',
#       'expanded_url': 'https://twitter.com/i/web/status/990975916506603521',
#       'display_url': 'twitter.com/i/web/status/9…',
#       'indices': [117, 140]}],
#     'user_mentions': [],
#     'symbols': []},
#    'favorited': False,
#    'retweeted': False,
#    'filter_level': 'low',
#    'lang': 'en'},
#   'is_quote_status': False,
#   'quote_count': 0,
#   'reply_count': 0,
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'entities': {'hashtags': [],
#    'urls': [],
#    'user_mentions': [{'screen_name': 'therealcbrad',
#      'name': 'therealcnothing',
#      'id': 1692592524,
#      'id_str': '1692592524',
#      'indices': [3, 16]}],
#    'symbols': []},
#   'favorited': False,
#   'retweeted': False,
#   'filter_level': 'low',
#   'lang': 'en',
#   'timestamp_ms': '1525102978007'},
#  {'created_at': 'Mon Apr 30 15:42:57 +0000 2018',
#   'id': 990979831239081984,
#   'id_str': '990979831239081984',
#   'text': 'LANDSHARK! + SALE Ben 10 Arrival Of Aliens[TEST] via @ROBLOX https://t.co/S6YC4lCIXP',
#   'source': '<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>',
#   'truncated': False,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 936674714038046722,
#    'id_str': '936674714038046722',
#    'name': 'ZonaR #TeamNombres',
#    'screen_name': 'Zolandeer',
#    'location': None,
#    'url': None,
#    'description': 'Si eres seguidor y quieres ganar cuentas ponte #TeamNombre',
#    'translator_type': 'none',
#    'protected': False,
#    'verified': False,
#    'followers_count': 109,
#    'friends_count': 469,
#    'listed_count': 0,
#    'favourites_count': 669,
#    'statuses_count': 1554,
#    'created_at': 'Fri Dec 01 19:13:49 +0000 2017',
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'lang': 'es',
#    'contributors_enabled': False,
#    'is_translator': False,
#    'profile_background_color': '000000',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_link_color': '19CF86',
#    'profile_sidebar_border_color': '000000',
#    'profile_sidebar_fill_color': '000000',
#    'profile_text_color': '000000',
#    'profile_use_background_image': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/971965039832739840/iywAvm_f_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/971965039832739840/iywAvm_f_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/936674714038046722/1520394817',
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': None,
#    'follow_request_sent': None,
#    'notifications': None},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'is_quote_status': False,
#   'quote_count': 0,
#   'reply_count': 0,
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'entities': {'hashtags': [],
#    'urls': [{'url': 'https://t.co/S6YC4lCIXP',
#      'expanded_url': 'http://fw.to/KH12BtP',
#      'display_url': 'fw.to/KH12BtP',
#      'indices': [61, 84]}],
#    'user_mentions': [{'screen_name': 'Roblox',
#      'name': 'Roblox',
#      'id': 16745055,
#      'id_str': '16745055',
#      'indices': [53, 60]}],
#    'symbols': []},
#   'favorited': False,
#   'retweeted': False,
#   'possibly_sensitive': False,
#   'filter_level': 'low',
#   'lang': 'en',
#   'timestamp_ms': '1525102977939'},
#  {'created_at': 'Mon Apr 30 15:42:59 +0000 2018',
#   'id': 990979837375467520,
#   'id_str': '990979837375467520',
#   'text': 'RT @purplemeatballs: 🚨"April 1, 2018, illegal aliens in #California who have recently obtained state driver\'s licenses legally, or obtained…',
#   'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#   'truncated': False,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 3884926699,
#    'id_str': '3884926699',
#    'name': 'Mimi',
#    'screen_name': 'Mimi38760907',
#    'location': None,
#    'url': None,
#    'description': "Can't stop saying it, President \nDonald J Trump\n*Vote the Person not the Party\n\nBots are blocked.",
#    'translator_type': 'none',
#    'protected': False,
#    'verified': False,
#    'followers_count': 1190,
#    'friends_count': 125,
#    'listed_count': 86,
#    'favourites_count': 112906,
#    'statuses_count': 119701,
#    'created_at': 'Tue Oct 13 21:52:03 +0000 2015',
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'lang': 'en',
#    'contributors_enabled': False,
#    'is_translator': False,
#    'profile_background_color': 'C0DEED',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/692361246046359552/R05D0dZ8_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/692361246046359552/R05D0dZ8_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/3884926699/1478895092',
#    'default_profile': True,
#    'default_profile_image': False,
#    'following': None,
#    'follow_request_sent': None,
#    'notifications': None},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'retweeted_status': {'created_at': 'Mon Apr 30 15:37:35 +0000 2018',
#    'id': 990978479851261952,
#    'id_str': '990978479851261952',
#    'text': '🚨"April 1, 2018, illegal aliens in #California who have recently obtained state driver\'s licenses legally, or obtai… https://t.co/pP68KMUFJy',
#    'source': '<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>',
#    'truncated': True,
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 4214995979,
#     'id_str': '4214995979',
#     'name': 'Gay & Deplorable',
#     'screen_name': 'purplemeatballs',
#     'location': None,
#     'url': 'https://youtu.be/prO7R1l2kZI',
#     'description': '📚Real Facts not Feelings 📚 40 yrs in business 📈\n2 degrees & MBA 💻\nRespect 4 👄🐈️🐕🐸💒🗽 Genetics: 1/2 Black 1/2 White\n😴 Retired 🌈 Gay💘Love #Trump',
#     'translator_type': 'none',
#     'protected': False,
#     'verified': False,
#     'followers_count': 7225,
#     'friends_count': 7941,
#     'listed_count': 132,
#     'favourites_count': 81267,
#     'statuses_count': 63940,
#     'created_at': 'Wed Nov 18 03:40:52 +0000 2015',
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': True,
#     'lang': 'en',
#     'contributors_enabled': False,
#     'is_translator': False,
#     'profile_background_color': '000000',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_link_color': '981CEB',
#     'profile_sidebar_border_color': '000000',
#     'profile_sidebar_fill_color': '000000',
#     'profile_text_color': '000000',
#     'profile_use_background_image': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/936996814636457986/g_ANTwxb_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/936996814636457986/g_ANTwxb_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/4214995979/1484549904',
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': None,
#     'follow_request_sent': None,
#     'notifications': None},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'extended_tweet': {'full_text': '🚨"April 1, 2018, illegal aliens in #California who have recently obtained state driver\'s licenses legally, or obtained them previously by lying about their immigration status, will automatically be registered to vote." \n@realDonaldTrump @RealCandaceO \nhttps://t.co/bvmeLXPm7y',
#     'display_text_range': [0, 275],
#     'entities': {'hashtags': [{'text': 'California', 'indices': [35, 46]}],
#      'urls': [{'url': 'https://t.co/bvmeLXPm7y',
#        'expanded_url': 'https://tinyurl.com/y7o6fuyg',
#        'display_url': 'tinyurl.com/y7o6fuyg',
#        'indices': [252, 275]}],
#      'user_mentions': [{'screen_name': 'realDonaldTrump',
#        'name': 'Donald J. Trump',
#        'id': 25073877,
#        'id_str': '25073877',
#        'indices': [220, 236]},
#       {'screen_name': 'RealCandaceO',
#        'name': 'Candace Owens',
#        'id': 878247600096509952,
#        'id_str': '878247600096509952',
#        'indices': [237, 250]}],
#      'symbols': []}},
#    'quote_count': 0,
#    'reply_count': 0,
#    'retweet_count': 2,
#    'favorite_count': 1,
#    'entities': {'hashtags': [{'text': 'California', 'indices': [35, 46]}],
#     'urls': [{'url': 'https://t.co/pP68KMUFJy',
#       'expanded_url': 'https://twitter.com/i/web/status/990978479851261952',
#       'display_url': 'twitter.com/i/web/status/9…',
#       'indices': [117, 140]}],
#     'user_mentions': [],
#     'symbols': []},
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'filter_level': 'low',
#    'lang': 'en'},
#   'is_quote_status': False,
#   'quote_count': 0,
#   'reply_count': 0,
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'entities': {'hashtags': [{'text': 'California', 'indices': [56, 67]}],
#    'urls': [],
#    'user_mentions': [{'screen_name': 'purplemeatballs',
#      'name': 'Gay & Deplorable',
#      'id': 4214995979,
#      'id_str': '4214995979',
#      'indices': [3, 19]}],
#    'symbols': []},
#   'favorited': False,
#   'retweeted': False,
#   'filter_level': 'low',
#   'lang': 'en',
#   'timestamp_ms': '1525102979402'}]
